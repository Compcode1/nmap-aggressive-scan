# %% [markdown]
# Windows PowerShell
# Copyright (C) Microsoft Corporation. All rights reserved.
#
# Install the latest PowerShell for new features and improvements! https://aka.ms/PSWindows
#
# PS C:\Users\Steve> nmap -A scanme.nmap.org
# Starting Nmap 7.95 ( https://nmap.org ) at 2025-04-02 11:43 Pacific Daylight Time
# Nmap scan report for scanme.nmap.org (45.33.32.156)
# Host is up (0.058s latency).
# Other addresses for scanme.nmap.org (not scanned): 2600:3c01::f03c:91ff:fe18:bb2f
# Not shown: 991 closed tcp ports (reset)
# PORT      STATE    SERVICE      VERSION
# 22/tcp    open     ssh          OpenSSH 6.6.1p1 Ubuntu 2ubuntu2.13 (Ubuntu Linux; protocol 2.0)
# | ssh-hostkey:
# |   1024 ac:00:a0:1a:82:ff:cc:55:99:dc:67:2b:34:97:6b:75 (DSA)
# |   2048 20:3d:2d:44:62:2a:b0:5a:9d:b5:b3:05:14:c2:a6:b2 (RSA)
# |   256 96:02:bb:5e:57:54:1c:4e:45:2f:56:4c:4a:24:b2:57 (ECDSA)
# |_  256 33:fa:91:0f:e0:e1:7b:1f:6d:05:a2:b0:f1:54:41:56 (ED25519)
# 25/tcp    filtered smtp
# 80/tcp    open     http         Apache httpd 2.4.7 ((Ubuntu))
# |_http-favicon: Nmap Project
# |_http-server-header: Apache/2.4.7 (Ubuntu)
# |_http-title: Go ahead and ScanMe!
# 111/tcp   filtered rpcbind
# 135/tcp   filtered msrpc
# 139/tcp   filtered netbios-ssn
# 445/tcp   filtered microsoft-ds
# 9929/tcp  open     nping-echo   Nping echo
# 31337/tcp open     tcpwrapped
# Device type: general purpose|router
# Running: Linux 5.X, MikroTik RouterOS 7.X
# OS CPE: cpe:/o:linux:linux_kernel:5 cpe:/o:mikrotik:routeros:7 cpe:/o:linux:linux_kernel:5.6.3
# OS details: Linux 5.0 - 5.14, MikroTik RouterOS 7.2 - 7.5 (Linux 5.6.3)
# Network Distance: 11 hops
# Service Info: OS: Linux; CPE: cpe:/o:linux:linux_kernel
#
# TRACEROUTE (using port 3306/tcp)
# HOP RTT       ADDRESS
# 1   139.00 ms dsldevice.attlocal.net (192.168.1.254)
# 2   ... 3
# 4   99.00 ms  32.130.88.90
# 5   252.00 ms 32.130.20.158
# 6   103.00 ms 32.130.104.175
# 7   252.00 ms ae22.gw3.scz1.netarch.akamai.com (23.203.158.51)
# 8   ... 10
# 11  253.00 ms scanme.nmap.org (45.33.32.156)
#
# OS and Service detection performed. Please report any incorrect results at https://nmap.org/submit/ .
# Nmap done: 1 IP address (1 host up) scanned in 21.89 seconds
# PS C:\Users\Steve>

# %% [markdown]
# PS C:\Users\Steve> nmap -A scanme.nmap.org
# Explanation:
# **This is the command issued in PowerShell. nmap is the tool; -A is a switch that enables aggressive scanning (OS detection, version detection, script scanning, and traceroute); scanme.nmap.org is the target domain owned by the Nmap project for safe public scanning.**
#
# **Starting Nmap 7.95 ( https://nmap.org ) at 2025-04-02 11:43 Pacific Daylight Time**
# Explanation:
# Nmap version 7.95 was used. The scan started on April 2, 2025, at 11:43 AM PDT.
#
# **Nmap scan report for scanme.nmap.org (45.33.32.156)**
# Explanation:
# Nmap resolved the domain name scanme.nmap.org to the IP address 45.33.32.156. This is the IP that will be scanned.
#
# **Host is up (0.058s latency).**
# Explanation:
# The host responded to a probe (typically ICMP or TCP), confirming it is online. Round-trip latency was 58 milliseconds.
#
# **Other addresses for scanme.nmap.org (not scanned): 2600:3c01::f03c:91ff:fe18:bb2f**
# Explanation:
# The domain has an IPv6 address in addition to the IPv4 address scanned. The IPv6 address was not scanned in this run.
#
# **Not shown: 991 closed tcp ports (reset)**
# Explanation:
# Nmap scanned exactly 1,000 of the most common TCP ports. Of these, 991 were marked as closed, meaning the target actively rejected the connection attempts by sending back **TCP RST (reset) packets. A TCP RST packet is used to abruptly terminate or deny a connection, indicating that no service is listening on that port.**
#
# **PORT STATE SERVICE VERSION**
# Explanation:
# This is the table header describing the following output columns: port number, status (open/filtered/etc.), service typically associated with the port, and the detected version of that service.
#
# **22/tcp open ssh OpenSSH 6.6.1p1 Ubuntu 2ubuntu2.13 (Ubuntu Linux; protocol 2.0)**
# Explanation:
# Port 22 is open and running the SSH service. The specific implementation is OpenSSH version 6.6.1p1, on Ubuntu Linux. Protocol 2.0 is the secure, modern version of SSH.
#
# **| ssh-hostkey:**
# Explanation:
# Nmap ran a script to enumerate the SSH host keys used by the server, which help uniquely identify the server.
#
# **| 1024 ac:00:a0:1a:82:ff:cc:55:99:dc:67:2b:34:97:6b:75 (DSA)**
# Explanation:
# This is a 1024-bit DSA (Digital Signature Algorithm) public SSH host key fingerprint.
#
# **| 2048 20:3d:2d:44:62:2a:b0:5a:9d:b5:b3:05:14:c2:a6:b2 (RSA)**
# Explanation:
# This is a 2048-bit RSA host key fingerprint.
#
# **| 256 96:02:bb:5e:57:54:1c:4e:45:2f:56:4c:4a:24:b2:57 (ECDSA)**
# Explanation:
# This is a 256-bit ECDSA (Elliptic Curve Digital Signature Algorithm) host key fingerprint.
#
# **|_ 256 33:fa:91:0f:e0:e1:7b:1f:6d:05:a2:b0:f1:54:41:56 (ED25519)**
# Explanation:
# Another 256-bit key, using the Ed25519 algorithm, which is a high-speed elliptic curve signature scheme.
#
#
#   **SSH Host Key Enumeration Explanation**
# Nmap ran its ssh-hostkey script to enumerate the cryptographic keys used by the Secure Shell (SSH) service. These host keys are critical for establishing trust during a SSH connection. They ensure the client is connecting to the correct server and not an impostor.
#
# Each key type below represents a public key used by the server to authenticate itself. These keys are hashed and displayed as fingerprints, which are short representations of the full key that can be used to verify identity.
#
# **1. DSA (Digital Signature Algorithm) — 1024-bit**
# Purpose: DSA is used only for digital signatures, not for encryption. It proves the identity of the server by signing a message that the client can verify using the server's public key.
#
# Why it appears: Older systems often include a DSA key for compatibility, though DSA is considered deprecated in modern environments.
#
# What “fingerprint” means here: This is a hash of the public DSA key. Clients can compare it with a known good fingerprint to detect tampering.
#
# **2. RSA (Rivest–Shamir–Adleman) — 2048-bit**
# Purpose: RSA is a widely-used asymmetric encryption algorithm. In SSH, it is used for both server authentication and key exchange.
#
# Why it appears: RSA keys are still very common due to their support across a wide range of SSH clients and servers.
#
# What “fingerprint” means here: It’s a digest (shortened hash) of the server’s RSA public key. When you first connect to an SSH server, you’re usually shown the fingerprint so you can verify its identity.
#
# **3. ECDSA (Elliptic Curve Digital Signature Algorithm) — 256-bit**
# Purpose: ECDSA is a modern, efficient algorithm for digital signatures using elliptic curve cryptography. It offers strong security with smaller key sizes.
#
# Why it appears: Many modern servers use ECDSA because it provides the same security as RSA with faster computations and smaller keys.
#
# Fingerprint: Just like the others, this is a unique hash of the server’s ECDSA public key, used to confirm authenticity during SSH connections.
#
# **4. ED25519 — 256-bit**
# Purpose: ED25519 is a newer elliptic curve algorithm known for high security, resistance to side-channel attacks, and speed. It is used only for digital signatures.
#
# Why it appears: This is becoming the preferred key type in modern deployments due to its performance and strong cryptographic design.
#
# Fingerprint: A cryptographic summary (hash) of the ED25519 public key, used for secure identity verification.
#
# **Summary**
# A host key is the server's cryptographic identity in SSH.
#
# A fingerprint is a shortened hash of that key used for **visual verification.**
#
# Nmap lists these keys to allow administrators or security analysts to verify which key types are exposed and confirm that they match expected values.
#
# **25/tcp filtered smtp**
# Explanation:
# Port 25 (used for SMTP) is filtered, which means the scan received no response. A firewall may be dropping the packets.
#
# **80/tcp open http Apache httpd 2.4.7 ((Ubuntu))**
# Explanation:
# Port 80 (HTTP) is open and running Apache web server version 2.4.7 on Ubuntu.
# **httpd stands for HTTP Daemon.**
# A daemon is a background process that runs on Unix/Linux systems to provide a service — in this case, serving web pages.
# So httpd is simply the web server software running on the system. It's the process that listens on port 80 (HTTP) and responds to web requests.
#
#
# **|_http-favicon: Nmap Project**
# Explanation:
# The favicon (icon) returned by the web server is recognized as belonging to the Nmap project website.
# A favicon is the little icon you see in your browser tab when you visit a website. It's often a small logo or graphic.
# Web servers often include this icon as part of their website content — it's usually found at /favicon.ico.
# Nmap, during an aggressive scan (-A), downloads the favicon and compares its hash (digital signature) to a database of known favicons.
# In this case, the favicon returned by the web server matches the one used on the Nmap Project’s official website.
#
# **|_http-server-header: Apache/2.4.7 (Ubuntu)**
# Explanation:
# The server’s HTTP response headers indicate it's running Apache version 2.4.7 on Ubuntu.
# Exposed version numbers in response headers are often used by attackers to check for known vulnerabilities.
# A known version like Apache 2.4.7 on Ubuntu can be cross-checked in vulnerability databases to see if it’s exploitable (e.g., CVEs).
# Many security tools or hardened systems disable or obfuscate these headers to avoid leaking too much information.
#
# **|_http-title: Go ahead and ScanMe!**
# Explanation:
# The HTML <title> of the page is "Go ahead and ScanMe!", showing the page's visible tab name.
# This title is what you see on the browser tab or window title bar.
# Nmap uses a script (http-title) to grab the HTML, parse it, and extract that string.
#
#
# **111/tcp filtered rpcbind**
# **135/tcp filtered msrpc**
# **139/tcp filtered netbios-ssn**
# **445/tcp filtered microsoft-ds**
#
# **Explanation for all four lines:**
# Ports associated with various RPC and SMB services are filtered, meaning Nmap received no response. They are not necessarily closed, but responses are blocked, possibly by a firewall.
# This title is what you see on the browser tab or window title bar.
# Summary: Filtered Ports and Their Roles
#
# Port 111 (rpcbind)
# Service Name: rpcbind
# Protocol: Remote Procedure Call (RPC) – primarily used in Linux/UNIX systems
# Role: Maps RPC program numbers to actual network port numbers
# Ties to SMB: No direct connection, but supports adjacent remote services
#
# Port 135 (msrpc)
# Service Name: Microsoft RPC (msrpc)
# Protocol: Windows Remote Procedure Call (DCOM)
# Role: Handles service requests for remote management and control
# Ties to SMB: Yes, it's used by services that may initiate SMB connections or depend on it
#
# Port 139 (netbios-ssn)
# Service Name: NetBIOS Session Service
# Protocol: SMB over NetBIOS (SMBv1)
# Role: Used for legacy file and printer sharing on older Windows systems
# Ties to SMB: Yes, part of the original SMB transport method
#
# Port 445 (microsoft-ds)
# Service Name: Microsoft Directory Services
# tocol: Direct SMB over TCP (SMBv2/SMBv3)
# Role: Supports modern Windows file sharing, printer sharing, and Active Directory
# Ties to SMB: Yes, this is the primary port for SMB today
#
# **9929/tcp open nping-echo Nping echo**
# Explanation:
# Port 9929 is open and running the Nping echo service, used for testing and demonstration by Nmap.
#
# **31337/tcp open tcpwrapped**
# Explanation:
# Port 31337 is open. Nmap detected that a service is running but couldn't identify it. "tcpwrapped" means the server accepted the TCP connection but immediately closed it before Nmap could interact. This is often done for security.
#
# **Device type: general purpose|router**
# Explanation:
# Nmap OS detection suggests the target is a general-purpose device (like a server) or a router.
#
# **Running: Linux 5.X, MikroTik RouterOS 7.X**
# Explanation:
# The host OS is identified as Linux kernel version 5.x, possibly with MikroTik RouterOS 7.x installed.
#
# **OS CPE: cpe:/o:linux:linux_kernel:5 cpe:/o:mikrotik:routeros:7 cpe:/o:linux:linux_kernel:5.6.3**
# Explanation:
# CPE (Common Platform Enumeration) identifiers describe the software platform. Here, Nmap lists Linux kernel 5.x and MikroTik RouterOS 7.
#
# **OS details: Linux 5.0 - 5.14, MikroTik RouterOS 7.2 - 7.5 (Linux 5.6.3)**
# Explanation:
# Nmap’s best guess is that the OS is Linux kernel version between 5.0 and 5.14, or MikroTik RouterOS versions 7.2 to 7.5 (based on Linux 5.6.3).
#
# **Network Distance: 11 hops**
# Explanation:
# Nmap estimates that the target is 11 router hops away from your machine.
#
# **Service Info: OS: Linux; CPE: cpe:/o:linux:linux_kernel**
# Explanation:
# The scan further confirms that the system is running Linux based on service fingerprinting.
# Common Platform Enumeration (CPE) is a standardized method used to identify software applications, operating systems, and hardware platforms. It's maintained by the National Institute of Standards and Technology (NIST) and forms part of the broader Security Content Automation Protocol (SCAP) used in vulnerability management systems.
# CPE = Structured identifier used to label a known OS or software version so it can be matched with public vulnerability data (e.g., CVEs).
# It helps systems automatically track and assess risk based on what's discovered in scans.
#
# **TRACEROUTE (using port 3306/tcp)**
# Explanation:
# Nmap performed a traceroute using TCP port 3306 (MySQL), showing the path your packets took to reach the target.
# A traceroute is a network diagnostic tool that maps the path packets take from your machine to a destination host, identifying each hop (intermediate router or gateway) along the way. It helps visualize how traffic flows through the internet and where delays or failures might occur.
#  Nmap performed a traceroute automatically because we used the -A flag (nmap -A scanme.nmap.org), which enables aggressive scanning, including OS detection, version detection, script scanning, and traceroute.
# When Nmap performs a TCP-based traceroute, it needs to send out probe packets to simulate real traffic.
# Instead of using ICMP (used in classic traceroute tools), Nmap often uses a TCP SYN packet to an open port — or if no common ports are open, it selects a likely-to-be-closed port, like TCP 3306, which is commonly associated with MySQL.
# It uses this port not because it expects MySQL, but simply as a carrier for the traceroute packets.
# This trick often gets past firewalls that block ICMP or other common traceroute methods.
# Each "hop" in the output represents a device (usually a router) that the packet passed through on its way to the final destination.
#
# **HOP RTT ADDRESS**
# Explanation:
# This is the header for the traceroute table: hop number, round-trip time (RTT), and the IP address (or hostname) at that hop.
#
# **1 139.00 ms dsldevice.attlocal.net (192.168.1.254)**
# Explanation:
# First hop is your local router (192.168.1.254). The RTT was 139 milliseconds.
#
# **2 ... 3**
# Explanation:
# Hops 2 and 3 did not return responses, so they are not listed.
#
# 4 99.00 ms 32.130.88.90
# 5 252.00 ms 32.130.20.158
# 6 103.00 ms 32.130.104.175
# 7 252.00 ms ae22.gw3.scz1.netarch.akamai.com (23.203.158.51)
# 8 ... 10
# Explanation:
# Intermediate hops through ISP and backbone routers. Some hops did not respond. Round-trip times vary due to network path differences.
#
# **11 253.00 ms scanme.nmap.org (45.33.32.156)**
# Explanation:
# Final destination (scanme.nmap.org) was reached at hop 11 with 253ms latency.
#
# **OS and Service detection performed. Please report any incorrect results at https://nmap.org/submit/ .**
# Explanation:
# A notice that OS/service detection was run and errors can be reported to improve Nmap accuracy.
#
# **Nmap done: 1 IP address (1 host up) scanned in 21.89 seconds**
# Explanation:
# The scan completed in just under 22 seconds. One host was found online and scanned.

# %% [markdown]
# **Conclusion**
#
# This project demonstrated the power of Nmap as a network discovery and reconnaissance tool, capable of revealing detailed information about a target host. We used the aggressive scan mode (-A), which combines several advanced features into a single comprehensive scan:
#
# **Operating System Detection** attempts to identify the underlying OS of the target system (e.g., Linux, Windows) by analyzing network response behavior and fingerprinting packet signatures. This helps the scanner infer the software stack and potential vulnerabilities.
#
# **Service/Version Identification**probes open ports and examines the responses from services running on those ports (such as SSH, HTTP, or SMTP) to determine what applications are active and what versions they are running. For example, it might identify that Apache 2.4.7 is running on port 80. This is crucial for identifying vulnerable or outdated software.
#
# **Script Scanning** runs specialized Nmap Scripting Engine (NSE) scripts against detected services. These scripts can check for configuration issues, vulnerabilities, metadata leaks, or other information about the service. For example, NSE scripts might extract SSH host keys or HTTP headers.
#
# **Traceroute** maps the network path that packets take to reach the target, identifying each router (or “hop”) along the way. This helps visualize the network topology and locate potential bottlenecks, segmentation points, or firewall boundaries.
#
# The result was a highly informative output that exposed open ports, active services, software versions, OS details, and internal configurations such as SSH keys and HTTP metadata. While this scan was run against a safe, publicly available testing target (scanme.nmap.org), it clearly illustrates why attackers frequently use aggressive scanning to fingerprint external systems and prepare for exploitation.
#
# When network defenses allow scans like this to succeed, they can give adversaries a significant head start. For cybersecurity defenders, understanding the capabilities and risks of aggressive scanning is essential. It reinforces the need for strict firewall policies, service hardening, network segmentation, and monitoring to limit what an outsider can learn from an unauthenticated scan alone.
#
# The aggressive scan (nmap -A) covers approximately 60–70% of the most commonly used features of Nmap — especially those relevant to reconnaissance and security assessment. While it doesn’t cover every possible capability, it bundles together four of the most powerful and informative scan types, making it one of the most information-rich single commands in Nmap.
#
# What it does not include:
#
# Full UDP scanning (-sU)
#
# Intense scanning modes with custom timing (-T4, -T5)
#
# All NSE scripts (--script all)
#
# Firewall evasion options
#
# Spoofing, decoy scans, or stealth scanning (-S, -D, -sS)
#
# Custom packet crafting or fragmentation (--data-length, --mtu)
